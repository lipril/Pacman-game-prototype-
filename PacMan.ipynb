# %%
import pygame
import sys

# Initialize the pygame library
pygame.init()

# Define some constants
WIDTH, HEIGHT = 640, 480
RADIUS = 12
SPEED = 5
WHITE = (255, 255, 255)
YELLOW = (255, 255, 102)
BLACK = (0, 0, 0)

# Create the game screen
screen = pygame.display.set_mode((WIDTH, HEIGHT))

# Create the Pacman character
position = [WIDTH // 2, HEIGHT // 2]
direction = [1, 0]

# Create the food
food = [(WIDTH // 2, HEIGHT // 2)]

# Create the walls
walls = [(0, 0), (WIDTH, 0), (WIDTH, HEIGHT), (0, HEIGHT)]

# Create the ghosts
ghosts = [(WIDTH // 4, HEIGHT // 4), (WIDTH * 3 // 4, HEIGHT // 4), (WIDTH // 4, HEIGHT * 3 // 4), (WIDTH * 3 // 4, HEIGHT * 3 // 4)]

# Create a function to draw the Pacman character
def draw_pacman(position, direction):
    x, y = position
    dx, dy = direction
    angle = (dx * 90 - 45) % 360
    pygame.draw.arc(screen, YELLOW, (x - RADIUS, y - RADIUS, 2 * RADIUS, 2 * RADIUS), angle - 90, angle + 90, 2)

# Create a function to draw the food
def draw_food(food):
    for f in food:
        pygame.draw.circle(screen, WHITE, f, 5)

# Create a function to draw the walls
def draw_walls(walls):
    for w in walls:
        pygame.draw.rect(screen, WHITE, pygame.Rect(w[0], w[1], 10, 10))

# Create a function to draw the ghosts
def draw_ghosts(ghosts):
    for g in ghosts:
        pygame.draw.rect(screen, WHITE, pygame.Rect(g[0], g[1], 10, 10))

# Run the game loop
while True:
    # Handle events
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()

    # Move the Pacman character
    keys = pygame.key.get_pressed()
    if keys[pygame.K_UP]:
        direction = [0, -1]
    if keys[pygame.K_DOWN]:
        direction = [0, 1]
    if keys[pygame.K_LEFT]:
        direction = [-1, 0]
    if keys[pygame.K_RIGHT]:
        direction = [1, 0]
    position[0] += direction[0] * SPEED
    position[1] += direction[1] * SPEED

    # Check for collisions with the walls
    if [position[0], position[1]] in walls:
        position[0] -= direction[0] * SPEED
        position[1] -= direction[1] * SPEED

    # Check for collisions with the food
    if [position[0], position[1]] in food:
        food.remove([position[0], position[1]])

    # Check for collisions with the ghosts
    for g in ghosts:
        if [position[0], position[1]] == g:
            pygame.quit()
            sys.exit()

    # Draw the game screen
    screen.fill(BLACK)
    draw_pacman(position, direction)
    draw_food(food
